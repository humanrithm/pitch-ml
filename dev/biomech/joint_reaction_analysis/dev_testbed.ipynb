# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('test_jra_JointReaction_ReactionLoads.sto', sep='\\s+', skiprows=11)

# %%
data['elbow_r_on_ulna_r_in_ulna_r_mx'].plot()
# Out:
# <Axes: >
