# %%
import pandas as pd
from connections.aws import AWS

# %%
""" INITIALIZE AWS CONNECTION """
aws_connection = AWS()
aws_connection.connect()
# Out:
# [AWS]: Port 5433 is free.
# [AWS]: Connected to RDS endpoint.

# %% [markdown]
# $\textbf{Butterworth Filtering}$
#
# See underlying details in `dev/biomech/dev_marker_filtering.ipynb`.

# %%
from biomech.processing.trc import *
from biomech.algorithms import butter_lowpass_filter

# %%
# load subject info
subject_info = aws_connection.load_subject_info()

# load trc files
s3_objects = aws_connection.list_s3_objects(prefix='subjects/')
trc_files = [obj for obj in s3_objects if obj.endswith('.trc') and '_static' not in obj and '_filtered' not in obj]        # filter for trc files

# %%
# error storage
errors = []

# iterate through trc files, apply filter, and upload to S3
for file in trc_files:
    
    # get subject info (ID, throws) if in subject_info; otherwise skip to next file
    subject_id = file.split('/')[1]
    if int(subject_id) in subject_info['subject_id'].values:
        subject_throws = subject_info[subject_info['subject_id'] == int(subject_id)]['throws'].values[0]
    else:
        continue
    
    try:
        # read trc file from S3
        trc_bytes = aws_connection.load_s3_object(file, return_info=False)
        trc_body = parse_trc_body(trc_bytes, adjust_time=True)
        
        # apply filter to trc body
        trc_filt_body = butter_lowpass_filter(
            data=trc_body, 
            columns=[col for col in trc_body.columns if col not in ['Frame#', 'Time']], 
            cutoff=18, 
            fs=480.0, 
            order=2
        )

        # create header (w/ _filtered file name)
        file_name = f"{file.split('/')[-1].split('.')[0]}_filtered.trc"
        trc_filt_header = create_trc_header(
            file_name,
            trc_filt_body,
            throwing_hand=subject_throws,
            frame_rate=480
        )
        
        # upload to S3 (trc_processed)
        upload_path = f'subjects/{subject_id}/trc_processed/{file_name}'
        aws_connection.upload_trc_to_s3(
        trc_filt_header,
        trc_filt_body,
        s3_key=upload_path
    )

    except Exception as e:
        print(f"Error processing file {file}: {e}")
        
        # log error with file name and error message
        errors.append({
            'file': file,
            'error': str(e)
        })

        continue
# Out:
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_10_filtered.trc
# Error processing file subjects/2609/trc_raw/2609_11.trc: The length of the input vector x must be greater than padlen, which is 9.
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2609/trc_processed/2609_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_11_filtered.trc
# Error processing file subjects/2610/trc_raw/2610_12.trc: Length of values (503) does not match length of index (502)
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2610/trc_processed/2610_windup07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_13-test_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_30_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_31_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_32_filtered.trc
# Error processing file subjects/2611/trc_raw/2611_33.trc: Length of values (506) does not match length of index (505)
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_34_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_35_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2611/trc_processed/2611_36_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2612/trc_processed/2612_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_09_filtered.trc
# Error processing file subjects/2613/trc_raw/2613_10.trc: Length of values (503) does not match length of index (502)
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_17_filtered.trc
# Error processing file subjects/2613/trc_raw/2613_18.trc: Length of values (478) does not match length of index (477)
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2613/trc_processed/2613_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2614/trc_processed/2614_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2616/trc_processed/2616_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2618/trc_processed/2618_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2619/trc_processed/2619_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2621/trc_processed/2621_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2622/trc_processed/2622_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2623/trc_processed/2623_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2624/trc_processed/2624_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2625/trc_processed/2625_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2627/trc_processed/2627_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2628/trc_processed/2628_30_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2629/trc_processed/2629_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2630/trc_processed/2630_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2631/trc_processed/2631_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2633/trc_processed/2633_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2633/trc_processed/2633_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2633/trc_processed/2633_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2634/trc_processed/2634_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_23_filtered.trc
# Error processing file subjects/2635/trc_raw/2635_24.trc: The length of the input vector x must be greater than padlen, which is 9.
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2635/trc_processed/2635_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_01_filtered.trc
# Error processing file subjects/2636/trc_raw/2636_02.trc: Length of values (1008) does not match length of index (1007)
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/2636/trc_processed/2636_17_filtered.trc
# ...
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3047/trc_processed/3047_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3050/trc_processed/3050_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3051/trc_processed/3051_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_29_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3052/trc_processed/3052_30_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_27_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3053/trc_processed/3053_28_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3054/trc_processed/3054_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_23_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_24_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_25_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3055/trc_processed/3055_26_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_01_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_02_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_03_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_04_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_05_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_06_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_07_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_08_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_09_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_10_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_11_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_12_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_13_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_14_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_15_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_16_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_17_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_18_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_19_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_20_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_21_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_22_filtered.trc
# [AWS]: TRC file written to s3://pitch-ml/subjects/3056/trc_processed/3056_23_filtered.trc

# %%
# write error trials to file for later investigation
error_trials_summary = pd.DataFrame(errors)
aws_connection.upload_to_s3(
    error_trials_summary,
    s3_key=f'subjects/summary/error_filtering_summary.csv'
)
# Out:
# [AWS]: Uploaded object to s3://pitch-ml/subjects/summary/error_filtering_summary.csv

# %%
# close connection
aws_connection.close()
# Out:
# [AWS]: Database connection closed.
# [AWS]: SSH tunnel stopped.
