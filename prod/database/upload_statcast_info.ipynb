# %%
import requests
import pandas as pd
from connections import AWS

# %%
""" INITIALIZE AWS CONNECTION """
aws_connection = AWS()
aws_connection.connect()
# Out:
# [AWS]: Port 5433 is free.
# [AWS]: Connected to RDS endpoint.

# %% [markdown]
# $\textbf{Statcast: Player Info Querying (Development)}$
#
# Pulls player mass & height from Statcast API for post-model analysis.

# %%
def get_player_bio(
        mlbam_id: int,
        url_stem: str = "https://statsapi.mlb.com/api/v1/people"
):
    """ 
    Fetches player biography information from MLB API.
    Args:
        mlbam_id (int): The MLBAM ID of the player.
        url_stem (str): The base URL for the MLB API endpoint.
    Returns:
        dict: A dictionary containing the player's name, height, and weight.
    """

    # create player URL
    url = f"{url_stem}/{mlbam_id}"

    # make request to API
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()

    # parse response (SI units)
    person = data['people'][0]
    name = person['fullName']
    height_ft = person['height'] 
    weight = person['weight']

    # metric conversions
    height = (int(height_ft.split('\'')[0]) * 30.48 + int(height_ft.split('\'')[1].split('"')[0]) * 2.54) / 100
    mass = int(weight) * 0.45359237

    return {
        'name': name,
        'height': height,
        'mass': mass,
    }

# %%
# load cohort (csv)
    # NOTE: new AWS module (v0.2.8) loads this directly as a dataframe
cohort = aws_connection.load_s3_object('epidemiology/cohorts/injured/combined_0625.csv')

# %%
# initialize full bio storage
full_bios = []

# iterate through cohort and get player bios
for player_id in cohort['mlbamid'].unique():
    try:
        player_bio = get_player_bio(player_id)
        player_bio['mlbamid'] = player_id  # add mlbamid to the bio
        full_bios.append(player_bio)
        
        # save player bio to S3
        aws_connection.upload_to_s3(
            pd.DataFrame([player_bio]),
            f'epidemiology/subjects/{player_id}/demographics.csv'
        )

        print(f"Successfully fetched and saved data for player ID {player_id}.")
    
    except requests.HTTPError as e:
        print(f"Failed to fetch data for player ID {player_id}: {e}")
    
    except Exception as e:
        print(f"An error occurred for player ID {player_id}: {e}")
# Out:
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/642678/demographics.csv
# Successfully fetched and saved data for player ID 642678.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641845/demographics.csv
# Successfully fetched and saved data for player ID 641845.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657570/demographics.csv
# Successfully fetched and saved data for player ID 657570.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/623406/demographics.csv
# Successfully fetched and saved data for player ID 623406.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/670155/demographics.csv
# Successfully fetched and saved data for player ID 670155.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641927/demographics.csv
# Successfully fetched and saved data for player ID 641927.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/596106/demographics.csv
# Successfully fetched and saved data for player ID 596106.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/670579/demographics.csv
# Successfully fetched and saved data for player ID 670579.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592238/demographics.csv
# Successfully fetched and saved data for player ID 592238.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/525768/demographics.csv
# Successfully fetched and saved data for player ID 525768.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657747/demographics.csv
# Successfully fetched and saved data for player ID 657747.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/506433/demographics.csv
# Successfully fetched and saved data for player ID 506433.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572831/demographics.csv
# Successfully fetched and saved data for player ID 572831.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666168/demographics.csv
# Successfully fetched and saved data for player ID 666168.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/430629/demographics.csv
# Successfully fetched and saved data for player ID 430629.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/615698/demographics.csv
# Successfully fetched and saved data for player ID 615698.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/621345/demographics.csv
# Successfully fetched and saved data for player ID 621345.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/554430/demographics.csv
# Successfully fetched and saved data for player ID 554430.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/

# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669723/demographics.csv
# Successfully fetched and saved data for player ID 669723.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592438/demographics.csv
# Successfully fetched and saved data for player ID 592438.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/571946/demographics.csv
# Successfully fetched and saved data for player ID 571946.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/474521/demographics.csv
# Successfully fetched and saved data for player ID 474521.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592361/demographics.csv
# Successfully fetched and saved data for player ID 592361.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/650306/demographics.csv
# Successfully fetched and saved data for player ID 650306.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543942/demographics.csv
# Successfully fetched and saved data for player ID 543942.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/685401/demographics.csv
# Successfully fetched and saved data for player ID 685401.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657060/demographics.csv
# Successfully fetched and saved data for player ID 657060.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/595897/demographics.csv
# Successfully fetched and saved data for player ID 595897.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/675963/demographics.csv
# Successfully fetched and saved data for player ID 675963.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/668716/demographics.csv
# Successfully fetched and saved data for player ID 668716.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687888/demographics.csv
# Successfully fetched and saved data for player ID 687888.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663386/demographics.csv
# Successfully fetched and saved data for player ID 663386.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694461/demographics.csv
# Successfully fetched and saved data for player ID 694461.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656563/demographics.csv
# Successfully fetched and saved data for player ID 656563.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/670299/demographics.csv
# Successfully fetched and saved data for player ID 670299.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669309/demographics.csv
# Successfully fetched and saved data for player ID 669309.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656548/demographics.csv
# Successfully fetched and saved data for player ID 656548.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666129/demographics.csv
# Successfully fetched and saved data for player ID 666129.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/650402/demographics.csv
# Successfully fetched and saved data for player ID 650402.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/594311/demographics.csv
# Successfully fetched and saved data for player ID 594311.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656031/demographics.csv
# Successfully fetched and saved data for player ID 656031.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663700/demographics.csv
# Successfully fetched and saved data for player ID 663700.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/474029/demographics.csv
# Successfully fetched and saved data for player ID 474029.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/476595/demographics.csv
# Successfully fetched and saved data for player ID 476595.
# ...
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/668909/demographics.csv
# Successfully fetched and saved data for player ID 668909.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608337/demographics.csv
# Successfully fetched and saved data for player ID 608337.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694331/demographics.csv
# Successfully fetched and saved data for player ID 694331.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669370/demographics.csv
# Successfully fetched and saved data for player ID 669370.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678258/demographics.csv
# Successfully fetched and saved data for player ID 678258.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/693433/demographics.csv
# Successfully fetched and saved data for player ID 693433.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/808632/demographics.csv
# Successfully fetched and saved data for player ID 808632.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/683349/demographics.csv
# Successfully fetched and saved data for player ID 683349.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679977/demographics.csv
# Successfully fetched and saved data for player ID 679977.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/815679/demographics.csv
# Successfully fetched and saved data for player ID 815679.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/800612/demographics.csv
# Successfully fetched and saved data for player ID 800612.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/683235/demographics.csv
# Successfully fetched and saved data for player ID 683235.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664285/demographics.csv
# Successfully fetched and saved data for player ID 664285.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/601713/demographics.csv
# Successfully fetched and saved data for player ID 601713.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681217/demographics.csv
# Successfully fetched and saved data for player ID 681217.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/691587/demographics.csv
# Successfully fetched and saved data for player ID 691587.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669684/demographics.csv
# Successfully fetched and saved data for player ID 669684.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607536/demographics.csv
# Successfully fetched and saved data for player ID 607536.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669194/demographics.csv
# Successfully fetched and saved data for player ID 669194.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687830/demographics.csv
# Successfully fetched and saved data for player ID 687830.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681006/demographics.csv
# Successfully fetched and saved data for player ID 681006.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679525/demographics.csv
# Successfully fetched and saved data for player ID 679525.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects

# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689981/demographics.csv
# Successfully fetched and saved data for player ID 689981.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/640470/demographics.csv
# Successfully fetched and saved data for player ID 640470.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/695573/demographics.csv
# Successfully fetched and saved data for player ID 695573.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/118901/demographics.csv
# Successfully fetched and saved data for player ID 118901.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665622/demographics.csv
# Successfully fetched and saved data for player ID 665622.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666745/demographics.csv
# Successfully fetched and saved data for player ID 666745.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678495/demographics.csv
# Successfully fetched and saved data for player ID 678495.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592155/demographics.csv
# Successfully fetched and saved data for player ID 592155.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/677053/demographics.csv
# Successfully fetched and saved data for player ID 677053.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608334/demographics.csv
# Successfully fetched and saved data for player ID 608334.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/408202/demographics.csv
# Successfully fetched and saved data for player ID 408202.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/622761/demographics.csv
# Successfully fetched and saved data for player ID 622761.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689149/demographics.csv
# Successfully fetched and saved data for player ID 689149.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681035/demographics.csv
# Successfully fetched and saved data for player ID 681035.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/804544/demographics.csv
# Successfully fetched and saved data for player ID 804544.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682227/demographics.csv
# Successfully fetched and saved data for player ID 682227.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/804526/demographics.csv
# Successfully fetched and saved data for player ID 804526.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689672/demographics.csv
# Successfully fetched and saved data for player ID 689672.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657514/demographics.csv
# Successfully fetched and saved data for player ID 657514.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669111/demographics.csv
# Successfully fetched and saved data for player ID 669111.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687924/demographics.csv
# Successfully fetched and saved data for player ID 687924.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/814366/demographics.csv
# Successfully fetched and saved data for player ID 814366.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/808207/demographics.csv
# Successfully fetched and saved data for player ID 808207.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681066/demographics.csv
# Successfully fetched and saved data for player ID 681066.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680570/demographics.csv
# Successfully fetched and saved data for player ID 680570.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/674003/demographics.csv
# Successfully fetched and saved data for player ID 674003.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/683003/demographics.csv
# Successfully fetched and saved data for player ID 683003.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/671162/demographics.csv
# Successfully fetched and saved data for player ID 671162.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669674/demographics.csv
# Successfully fetched and saved data for player ID 669674.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687792/demographics.csv
# Successfully fetched and saved data for player ID 687792.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/527048/demographics.csv
# Successfully fetched and saved data for player ID 527048.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664875/demographics.csv
# Successfully fetched and saved data for player ID 664875.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669302/demographics.csv
# Successfully fetched and saved data for player ID 669302.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/277415/demographics.csv
# Successfully fetched and saved data for player ID 277415.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669713/demographics.csv
# Successfully fetched and saved data for player ID 669713.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682243/demographics.csv
# Successfully fetched and saved data for player ID 682243.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/820862/demographics.csv
# Successfully fetched and saved data for player ID 820862.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/695549/demographics.csv
# Successfully fetched and saved data for player ID 695549.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669203/demographics.csv
# Successfully fetched and saved data for player ID 669203.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/594902/demographics.csv
# Successfully fetched and saved data for player ID 594902.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669854/demographics.csv
# Successfully fetched and saved data for player ID 669854.

# %%
# concatenate all bios and save to cohort folder
full_bios_df = pd.DataFrame(full_bios)
aws_connection.upload_to_s3(
    full_bios_df,
    'epidemiology/cohorts/injured/statcast_bios.csv'
)
# Out:
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/cohorts/injured/statcast_bios.csv

# %% [markdown]
# $\textbf{Close AWS Connection}$

# %%
aws_connection.close()
# Out:
# [AWS]: Database connection closed.
# [AWS]: SSH tunnel stopped.
