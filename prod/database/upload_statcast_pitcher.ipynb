# %%
import traceback
import pandas as pd
from connections import AWS
from pybaseball import statcast_pitcher, statcast

# %%
""" INITIALIZE AWS CONNECTION """
aws_connection = AWS()
aws_connection.connect()
# Out:
# [AWS]: Port 5433 is free.
# [AWS]: Connected to RDS endpoint.

# %%
# load cohort (csv)
    # NOTE: new AWS module (v0.2.8) loads this directly as a dataframe
cohort = aws_connection.load_s3_object('epidemiology/cohorts/injured/combined_0625.csv')

# %% [markdown]
# $\textbf{PyBaseball: Querying (Development)}$

# %%
def pull_statcast_data(
        pitcher_id: str, 
        start_date: str, 
        end_date: str,
        non_missing_cols: list = [
            'release_speed', 
            'release_spin_rate',
            'spin_axis', 
            'release_pos_x', 
            'release_pos_z',
            'ax', 
            'ay', 
            'az'
        ]
) -> pd.DataFrame:
    """
    Pulls Statcast data for a given pitcher within a specified date range. This essentially amounts to calling `statcast_pitcher` with 
    extra postprocessing steps.
    
    :param pitcher_id: The MLB ID of the pitcher.
    :param start_date: The start date for the data pull (YYYY-MM-DD).
    :param end_date: The end date for the data pull (YYYY-MM-DD).
    :param non_missing_cols: A list of columns that should not contain missing values.
    :return: A DataFrame containing the Statcast data for the pitcher.
    """

    # check for str pitcher_id
    if not isinstance(pitcher_id, str):
        pitcher_id = str(pitcher_id)
    
    # load raw data from statcast API
    raw_data = statcast_pitcher(
        start_dt=start_date, 
        end_dt=end_date,
        player_id=pitcher_id
    )    
    clean_data = raw_data.dropna(axis=0, subset=non_missing_cols, how='any')        # remove NAs to clean data

    return clean_data

# %%
# initialize data storage
full_metadata = {}
full_data = []
error_log = {}

# iterate through all pitcher IDs
for pitcher_id in cohort.sort_values(by='injury_date', ascending=False)['mlbamid'].unique():

    try:
        # get relevant pitcher info
        pitcher_inj_date = cohort.loc[cohort['mlbamid'] == pitcher_id, 'injury_date'].values[0]
        pitcher_inj_year = pitcher_inj_date.split('-')[0]   # extract year from injury date
        pitcher_inj_month = pitcher_inj_date.split('-')[1]  # extract month from injury date

        # pull data from Statcast API
            # date range starts at beginning of year of injury, ends at beginning of month after injury
        pitcher_statcast_data = pull_statcast_data(
            pitcher_id=pitcher_id,
            start_date=f'{pitcher_inj_year}-01-01',
            end_date=f'{pitcher_inj_year}-{str((int(pitcher_inj_month) + 1)).zfill(2)}-01',
        )
        pitcher_metadata = {
            'mlbamid': pitcher_id,
            'injured': 1,
            'injury_date': pitcher_inj_date,
            'tracked_pitches_prior_to_injury': pitcher_statcast_data.shape[0],
        }

        # update data storage
        if not pitcher_statcast_data.empty:
            full_data.append(pitcher_statcast_data)

            # save to S3
            aws_connection.create_s3_folder(f'epidemiology/subjects/{pitcher_id}')          # create folder in epidemiology/subjects
            aws_connection.upload_to_s3(
                pitcher_statcast_data, 
                s3_key=f'epidemiology/subjects/{pitcher_id}/ball_tracking.csv'
            )  
            aws_connection.upload_to_s3(
                pd.DataFrame([pitcher_metadata]), 
                s3_key=f'epidemiology/subjects/{pitcher_id}/metadata.csv'
            ) 
        
            # print progress
            print(f"Processed pitcher `{pitcher_id}` with {pitcher_statcast_data.shape[0]} pitches tracked prior to injury.")
        
        else:
            print(f"No data found for pitcher {pitcher_id} in the specified date range.")
        
        # add metadata to full dictionary
        full_metadata[pitcher_id] = pitcher_metadata
        
    except Exception as e:
        print(f"Error processing pitcher {pitcher_id}: {e}")
        traceback.print_exc()
        error_log[pitcher_id] = str(e)
# Out:
# Gathering Player Data
# [AWS]: Folder s3://pitch-ml/epidemiology/subjects/669854/ already exists.
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669854/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669854/metadata.csv
# Processed pitcher `669854` with 852 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/594902/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/594902/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/594902/metadata.csv
# Processed pitcher `594902` with 854 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669203/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669203/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669203/metadata.csv
# Processed pitcher `669203` with 1222 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/623465/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/623465/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/623465/metadata.csv
# Processed pitcher `623465` with 284 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/695549/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/695549/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/695549/metadata.csv
# Processed pitcher `695549` with 1091 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669713/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669713/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669713/metadata.csv
# Processed pitcher `669713` with 551 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/683003/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/683003/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/683003/metadata.csv
# Processed pitcher `683003` with 202 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/820862/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/820862/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/820862/metadata.csv
# Processed pitcher `820862` with 214 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/682243/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682243/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682243/metadata.csv
# Processed pitcher `682243` with 1005 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 277415 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669302/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669302/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669302/metadata.csv
# Processed pitcher `669302` with 620 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 669372 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664875/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664875/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664875/metadata.csv
# Processed pitcher `664875` with 309 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/527048/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/527048/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/527048/metadata.csv
# Processed pitcher `527048` with 510 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 657006 in the specified date range.
# Gathering Player Data
# No data found for pitcher 640462 in the specified date range.
# Gathering Player Data
# No data found for pitcher 687792 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669212/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669212/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669212/metadata.csv
# Processed pitcher `669212` with 185 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669674/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669674/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669674/metadata.csv
# Processed pitcher `669674` with 279 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/671162/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/671162/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/671162/metadata.csv
# Processed pitcher `671162` with 194 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/641482/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641482/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641482/metadata.csv
# Processed pitcher `641482` with 189 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/656756/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656756/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656756/metadata.csv
# Processed pitcher `656756` with 453 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/666745/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666745/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666745/metadata.csv
# Processed pitcher `666745` with 641 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664776/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664776/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664776/metadata.csv
# Processed pitcher `664776` with 168 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 506433 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/674003/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/674003/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/674003/metadata.csv
# Processed pitcher `674003` with 89 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/543037/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543037/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543037/metadata.csv
# Processed pitcher `543037` with 39 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/680570/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680570/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680570/metadata.csv
# Processed pitcher `680570` with 33 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/689672/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689672/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689672/metadata.csv
# Processed pitcher `689672` with 721 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 683068 in the specified date range.
# Gathering Player Data
# No data found for pitcher 681066 in the specified date range.
# Gathering Player Data
# No data found for pitcher 808207 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/687924/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687924/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687924/metadata.csv
# Processed pitcher `687924` with 549 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/605397/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605397/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605397/metadata.csv
# Processed pitcher `605397` with 840 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 814366 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/681035/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681035/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681035/metadata.csv
# Processed pitcher `681035` with 866 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/641755/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641755/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641755/metadata.csv
# Processed pitcher `641755` with 402 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663704/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663704/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663704/metadata.csv
# Processed pitcher `663704` with 26 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669111/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669111/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669111/metadata.csv
# Processed pitcher `669111` with 180 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/657514/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657514/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657514/metadata.csv
# Processed pitcher `657514` with 870 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/605488/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605488/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605488/metadata.csv
# Processed pitcher `605488` with 379 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/689149/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689149/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689149/metadata.csv
# Processed pitcher `689149` with 90 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 804544 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/656755/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656755/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656755/metadata.csv
# Processed pitcher `656755` with 68 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/682227/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682227/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/682227/metadata.csv
# Processed pitcher `682227` with 256 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 804526 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622761 in the specified date range.
# Gathering Player Data
# No data found for pitcher 408202 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/608334/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608334/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608334/metadata.csv
# Processed pitcher `608334` with 1353 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/677053/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/677053/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/677053/metadata.csv
# Processed pitcher `677053` with 1032 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/554340/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/554340/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/554340/metadata.csv
# Processed pitcher `554340` with 133 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/608678/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608678/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608678/metadata.csv
# Processed pitcher `608678` with 815 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/592155/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592155/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/592155/metadata.csv
# Processed pitcher `592155` with 719 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/678495/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678495/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678495/metadata.csv
# Processed pitcher `678495` with 837 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 668881 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/607192/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607192/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607192/metadata.csv
# Processed pitcher `607192` with 1492 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/641712/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641712/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641712/metadata.csv
# Processed pitcher `641712` with 667 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/640470/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/640470/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/640470/metadata.csv
# Processed pitcher `640470` with 329 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/665622/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665622/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665622/metadata.csv
# Processed pitcher `665622` with 720 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 118901 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657097 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/689981/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689981/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/689981/metadata.csv
# Processed pitcher `689981` with 295 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 807712 in the specified date range.
# Gathering Player Data
# No data found for pitcher 695573 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/694357/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694357/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694357/metadata.csv
# Processed pitcher `694357` with 114 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669165/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669165/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669165/metadata.csv
# Processed pitcher `669165` with 107 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686826/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686826/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686826/metadata.csv
# Processed pitcher `686826` with 1196 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/676775/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/676775/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/676775/metadata.csv
# Processed pitcher `676775` with 847 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/680686/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680686/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680686/metadata.csv
# Processed pitcher `680686` with 176 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/642239/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/642239/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/642239/metadata.csv
# Processed pitcher `642239` with 190 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/608566/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608566/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608566/metadata.csv
# Processed pitcher `608566` with 368 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/681806/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681806/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681806/metadata.csv
# Processed pitcher `681806` with 35 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663462/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663462/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663462/metadata.csv
# Processed pitcher `663462` with 237 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 622098 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/608331/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608331/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608331/metadata.csv
# Processed pitcher `608331` with 1718 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/656814/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656814/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656814/metadata.csv
# Processed pitcher `656814` with 139 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/657585/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657585/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657585/metadata.csv
# Processed pitcher `657585` with 754 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686580/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686580/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686580/metadata.csv
# Processed pitcher `686580` with 697 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/668933/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/668933/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/668933/metadata.csv
# Processed pitcher `668933` with 1342 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 641726 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/455119/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/455119/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/455119/metadata.csv
# Processed pitcher `455119` with 646 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 811296 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605447 in the specified date range.
# Gathering Player Data
# No data found for pitcher 805780 in the specified date range.
# Gathering Player Data
# No data found for pitcher 692030 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/678061/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678061/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/678061/metadata.csv
# Processed pitcher `678061` with 409 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 801787 in the specified date range.
# Gathering Player Data
# No data found for pitcher 808690 in the specified date range.
# Gathering Player Data
# No data found for pitcher 676680 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663776/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663776/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663776/metadata.csv
# Processed pitcher `663776` with 1521 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/661383/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/661383/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/661383/metadata.csv
# Processed pitcher `661383` with 24 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/688107/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/688107/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/688107/metadata.csv
# Processed pitcher `688107` with 399 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/680694/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680694/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/680694/metadata.csv
# Processed pitcher `680694` with 674 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/543056/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543056/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543056/metadata.csv
# Processed pitcher `543056` with 406 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686839/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686839/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686839/metadata.csv
# Processed pitcher `686839` with 8 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 669330 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/666201/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666201/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666201/metadata.csv
# Processed pitcher `666201` with 432 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/694462/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694462/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/694462/metadata.csv
# Processed pitcher `694462` with 167 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664299/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664299/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664299/metadata.csv
# Processed pitcher `664299` with 742 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664353/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664353/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664353/metadata.csv
# Processed pitcher `664353` with 41 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686796/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686796/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686796/metadata.csv
# Processed pitcher `686796` with 232 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/607644/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607644/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607644/metadata.csv
# Processed pitcher `607644` with 250 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 691384 in the specified date range.
# Gathering Player Data
# No data found for pitcher 677592 in the specified date range.
# Gathering Player Data
# No data found for pitcher 801573 in the specified date range.
# Gathering Player Data
# No data found for pitcher 682785 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/702566/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/702566/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/702566/metadata.csv
# Processed pitcher `702566` with 30 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 801700 in the specified date range.
# Gathering Player Data
# No data found for pitcher 676477 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/548384/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/548384/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/548384/metadata.csv
# Processed pitcher `548384` with 223 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/548389/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/548389/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/548389/metadata.csv
# Processed pitcher `548389` with 977 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/687798/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687798/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687798/metadata.csv
# Processed pitcher `687798` with 353 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/656234/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656234/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/656234/metadata.csv
# Processed pitcher `656234` with 399 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/670219/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/670219/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/670219/metadata.csv
# Processed pitcher `670219` with 39 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 686218 in the specified date range.
# Gathering Player Data
# No data found for pitcher 686610 in the specified date range.
# Gathering Player Data
# No data found for pitcher 666374 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/650960/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/650960/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/650960/metadata.csv
# Processed pitcher `650960` with 106 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 489119 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/554431/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/554431/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/554431/metadata.csv
# Processed pitcher `554431` with 713 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 701685 in the specified date range.
# Gathering Player Data
# No data found for pitcher 672715 in the specified date range.
# Gathering Player Data
# No data found for pitcher 596112 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/572955/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572955/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572955/metadata.csv
# Processed pitcher `572955` with 136 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 702255 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/679525/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679525/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679525/metadata.csv
# Processed pitcher `679525` with 395 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/681006/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681006/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681006/metadata.csv
# Processed pitcher `681006` with 18 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 687830 in the specified date range.
# Gathering Player Data
# No data found for pitcher 666200 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669194/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669194/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669194/metadata.csv
# Processed pitcher `669194` with 557 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/607536/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607536/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/607536/metadata.csv
# Processed pitcher `607536` with 446 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/660623/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/660623/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/660623/metadata.csv
# Processed pitcher `660623` with 182 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 675911 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622088 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669456/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669456/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669456/metadata.csv
# Processed pitcher `669456` with 1869 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669684/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669684/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669684/metadata.csv
# Processed pitcher `669684` with 106 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/691587/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/691587/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/691587/metadata.csv
# Processed pitcher `691587` with 138 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/681217/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681217/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/681217/metadata.csv
# Processed pitcher `681217` with 259 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/641627/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641627/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/641627/metadata.csv
# Processed pitcher `641627` with 238 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/601713/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/601713/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/601713/metadata.csv
# Processed pitcher `601713` with 315 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664285/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664285/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664285/metadata.csv
# Processed pitcher `664285` with 324 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 683235 in the specified date range.
# Gathering Player Data
# No data found for pitcher 815679 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/679977/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679977/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/679977/metadata.csv
# Processed pitcher `679977` with 24 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 642528 in the specified date range.
# Gathering Player Data
# No data found for pitcher 800612 in the specified date range.
# Gathering Player Data
# No data found for pitcher 669416 in the specified date range.
# Gathering Player Data
# No data found for pitcher 683349 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/543101/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543101/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/543101/metadata.csv
# Processed pitcher `543101` with 1508 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 808632 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663986 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/693433/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/693433/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/693433/metadata.csv
# Processed pitcher `693433` with 40 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664294/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664294/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664294/metadata.csv
# Processed pitcher `664294` with 65 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 678258 in the specified date range.
# Gathering Player Data
# No data found for pitcher 669370 in the specified date range.
# Gathering Player Data
# No data found for pitcher 694331 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663804 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/665734/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665734/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665734/metadata.csv
# Processed pitcher `665734` with 248 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669387/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669387/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669387/metadata.csv
# Processed pitcher `669387` with 508 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/608337/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608337/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/608337/metadata.csv
# Processed pitcher `608337` with 48 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 668909 in the specified date range.
# Gathering Player Data
# No data found for pitcher 688701 in the specified date range.
# Gathering Player Data
# No data found for pitcher 672629 in the specified date range.
# Gathering Player Data
# No data found for pitcher 679346 in the specified date range.
# Gathering Player Data
# No data found for pitcher 669947 in the specified date range.
# Gathering Player Data
# No data found for pitcher 685125 in the specified date range.
# Gathering Player Data
# No data found for pitcher 666168 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663546 in the specified date range.
# Gathering Player Data
# No data found for pitcher 678173 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663558/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663558/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663558/metadata.csv
# Processed pitcher `663558` with 814 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 699479 in the specified date range.
# Gathering Player Data
# No data found for pitcher 676205 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/642585/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/642585/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/642585/metadata.csv
# Processed pitcher `642585` with 1025 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/622780/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/622780/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/622780/metadata.csv
# Processed pitcher `622780` with 625 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/645261/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/645261/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/645261/metadata.csv
# Processed pitcher `645261` with 2836 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/623451/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/623451/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/623451/metadata.csv
# Processed pitcher `623451` with 226 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663372/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663372/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663372/metadata.csv
# Processed pitcher `663372` with 1010 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 691176 in the specified date range.
# Gathering Player Data
# No data found for pitcher 682985 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/657272/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657272/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/657272/metadata.csv
# Processed pitcher `657272` with 176 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/660271/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/660271/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/660271/metadata.csv
# Processed pitcher `660271` with 846 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/665625/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665625/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/665625/metadata.csv
# Processed pitcher `665625` with 913 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/666619/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666619/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666619/metadata.csv
# Processed pitcher `666619` with 1055 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686972/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686972/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686972/metadata.csv
# Processed pitcher `686972` with 64 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/686753/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686753/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/686753/metadata.csv
# Processed pitcher `686753` with 799 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 686934 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664062/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664062/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664062/metadata.csv
# Processed pitcher `664062` with 1664 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 690374 in the specified date range.
# Gathering Player Data
# No data found for pitcher 687562 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605288 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/595928/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/595928/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/595928/metadata.csv
# Processed pitcher `595928` with 761 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 663556 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/630023/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/630023/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/630023/metadata.csv
# Processed pitcher `630023` with 190 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664208/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664208/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664208/metadata.csv
# Processed pitcher `664208` with 887 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 687327 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/425844/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/425844/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/425844/metadata.csv
# Processed pitcher `425844` with 1884 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/664199/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664199/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/664199/metadata.csv
# Processed pitcher `664199` with 887 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/521230/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/521230/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/521230/metadata.csv
# Processed pitcher `521230` with 87 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 689441 in the specified date range.
# Gathering Player Data
# No data found for pitcher 681884 in the specified date range.
# Gathering Player Data
# No data found for pitcher 678184 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/666301/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666301/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/666301/metadata.csv
# Processed pitcher `666301` with 30 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/669804/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669804/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/669804/metadata.csv
# Processed pitcher `669804` with 52 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 683025 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/663753/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663753/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/663753/metadata.csv
# Processed pitcher `663753` with 174 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/674072/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/674072/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/674072/metadata.csv
# Processed pitcher `674072` with 1610 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/622608/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/622608/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/622608/metadata.csv
# Processed pitcher `622608` with 120 pitches tracked prior to injury.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/687312/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687312/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/687312/metadata.csv
# Processed pitcher `687312` with 36 pitches tracked prior to injury.
# Gathering Player Data
# ...
# Gathering Player Data
# No data found for pitcher 664747 in the specified date range.
# Gathering Player Data
# No data found for pitcher 668857 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/605476/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605476/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605476/metadata.csv
# Processed pitcher `605476` with 42 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 664142 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605495 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/572362/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572362/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572362/metadata.csv
# Processed pitcher `572362` with 204 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 660874 in the specified date range.
# Gathering Player Data
# No data found for pitcher 664485 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543031 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/605135/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605135/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/605135/metadata.csv
# Processed pitcher `605135` with 504 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 663383 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656586 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641402 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592166 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663671 in the specified date range.
# Gathering Player Data
# No data found for pitcher 668676 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/572038/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572038/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/572038/metadata.csv
# Processed pitcher `572038` with 12 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 595165 in the specified date range.
# Gathering Player Data
# No data found for pitcher 600887 in the specified date range.
# Gathering Player Data
# No data found for pitcher 669373 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592705 in the specified date range.
# Gathering Player Data
# No data found for pitcher 594835 in the specified date range.
# Gathering Player Data
# No data found for pitcher 525768 in the specified date range.
# Gathering Player Data
# No data found for pitcher 658063 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622223 in the specified date range.
# Gathering Player Data
# No data found for pitcher 670165 in the specified date range.
# Gathering Player Data
# [AWS]: Created folder s3://pitch-ml/epidemiology/subjects/467094/
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/467094/ball_tracking.csv
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/subjects/467094/metadata.csv
# Processed pitcher `467094` with 17 pitches tracked prior to injury.
# Gathering Player Data
# No data found for pitcher 605334 in the specified date range.
# Gathering Player Data
# No data found for pitcher 448159 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656626 in the specified date range.
# Gathering Player Data
# No data found for pitcher 570233 in the specified date range.
# Gathering Player Data
# No data found for pitcher 650864 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642005 in the specified date range.
# Gathering Player Data
# No data found for pitcher 690281 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657045 in the specified date range.
# Gathering Player Data
# No data found for pitcher 606471 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607171 in the specified date range.
# Gathering Player Data
# No data found for pitcher 627392 in the specified date range.
# Gathering Player Data
# No data found for pitcher 545064 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592139 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605374 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605169 in the specified date range.
# Gathering Player Data
# No data found for pitcher 680791 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607692 in the specified date range.
# Gathering Player Data
# No data found for pitcher 624573 in the specified date range.
# Gathering Player Data
# No data found for pitcher 668943 in the specified date range.
# Gathering Player Data
# No data found for pitcher 676831 in the specified date range.
# Gathering Player Data
# No data found for pitcher 667465 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641949 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663723 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641895 in the specified date range.
# Gathering Player Data
# No data found for pitcher 669649 in the specified date range.
# Gathering Player Data
# No data found for pitcher 594987 in the specified date range.
# Gathering Player Data
# No data found for pitcher 458681 in the specified date range.
# Gathering Player Data
# No data found for pitcher 650840 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605285 in the specified date range.
# Gathering Player Data
# No data found for pitcher 643344 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592145 in the specified date range.
# Gathering Player Data
# No data found for pitcher 571858 in the specified date range.
# Gathering Player Data
# No data found for pitcher 688010 in the specified date range.
# Gathering Player Data
# No data found for pitcher 518813 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607316 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656203 in the specified date range.
# Gathering Player Data
# No data found for pitcher 502578 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657265 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621403 in the specified date range.
# Gathering Player Data
# No data found for pitcher 644375 in the specified date range.
# Gathering Player Data
# No data found for pitcher 572089 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622506 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605795 in the specified date range.
# Gathering Player Data
# No data found for pitcher 664328 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607444 in the specified date range.
# Gathering Player Data
# No data found for pitcher 625349 in the specified date range.
# Gathering Player Data
# No data found for pitcher 571982 in the specified date range.
# Gathering Player Data
# No data found for pitcher 673966 in the specified date range.
# Gathering Player Data
# No data found for pitcher 600965 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607481 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592865 in the specified date range.
# Gathering Player Data
# No data found for pitcher 450306 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641797 in the specified date range.
# Gathering Player Data
# No data found for pitcher 502264 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642390 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642271 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641715 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663718 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605333 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657058 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657671 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642196 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663341 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641316 in the specified date range.
# Gathering Player Data
# No data found for pitcher 608341 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657596 in the specified date range.
# Gathering Player Data
# No data found for pitcher 643546 in the specified date range.
# Gathering Player Data
# No data found for pitcher 682447 in the specified date range.
# Gathering Player Data
# No data found for pitcher 430603 in the specified date range.
# Gathering Player Data
# No data found for pitcher 435045 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543023 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656976 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663995 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642098 in the specified date range.
# Gathering Player Data
# No data found for pitcher 674937 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621522 in the specified date range.
# Gathering Player Data
# No data found for pitcher 594589 in the specified date range.
# Gathering Player Data
# No data found for pitcher 624522 in the specified date range.
# Gathering Player Data
# No data found for pitcher 605240 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607193 in the specified date range.
# Gathering Player Data
# No data found for pitcher 675973 in the specified date range.
# Gathering Player Data
# No data found for pitcher 628715 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622747 in the specified date range.
# Gathering Player Data
# No data found for pitcher 519443 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663929 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621298 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663752 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656632 in the specified date range.
# Gathering Player Data
# No data found for pitcher 608381 in the specified date range.
# Gathering Player Data
# No data found for pitcher 600934 in the specified date range.
# Gathering Player Data
# No data found for pitcher 663773 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642674 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592468 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621057 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621173 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607180 in the specified date range.
# Gathering Player Data
# No data found for pitcher 595032 in the specified date range.
# Gathering Player Data
# No data found for pitcher 622273 in the specified date range.
# Gathering Player Data
# No data found for pitcher 502171 in the specified date range.
# Gathering Player Data
# No data found for pitcher 606532 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543483 in the specified date range.
# Gathering Player Data
# No data found for pitcher 456701 in the specified date range.
# Gathering Player Data
# No data found for pitcher 493603 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657796 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621593 in the specified date range.
# Gathering Player Data
# No data found for pitcher 593619 in the specified date range.
# Gathering Player Data
# No data found for pitcher 544371 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656362 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656297 in the specified date range.
# Gathering Player Data
# No data found for pitcher 607696 in the specified date range.
# Gathering Player Data
# No data found for pitcher 435221 in the specified date range.
# Gathering Player Data
# No data found for pitcher 150274 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621399 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642125 in the specified date range.
# Gathering Player Data
# No data found for pitcher 570810 in the specified date range.
# Gathering Player Data
# No data found for pitcher 664055 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621258 in the specified date range.
# Gathering Player Data
# No data found for pitcher 626929 in the specified date range.
# Gathering Player Data
# No data found for pitcher 576968 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543297 in the specified date range.
# Gathering Player Data
# No data found for pitcher 571786 in the specified date range.
# Gathering Player Data
# No data found for pitcher 542918 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543070 in the specified date range.
# Gathering Player Data
# No data found for pitcher 572143 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641445 in the specified date range.
# Gathering Player Data
# No data found for pitcher 543877 in the specified date range.
# Gathering Player Data
# No data found for pitcher 623454 in the specified date range.
# Gathering Player Data
# No data found for pitcher 676705 in the specified date range.
# Gathering Player Data
# No data found for pitcher 643232 in the specified date range.
# Gathering Player Data
# No data found for pitcher 542231 in the specified date range.
# Gathering Player Data
# No data found for pitcher 544621 in the specified date range.
# Gathering Player Data
# No data found for pitcher 593334 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656223 in the specified date range.
# Gathering Player Data
# No data found for pitcher 656184 in the specified date range.
# Gathering Player Data
# No data found for pitcher 554430 in the specified date range.
# Gathering Player Data
# No data found for pitcher 621345 in the specified date range.
# Gathering Player Data
# No data found for pitcher 615698 in the specified date range.
# Gathering Player Data
# No data found for pitcher 430629 in the specified date range.
# Gathering Player Data
# No data found for pitcher 572831 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657747 in the specified date range.
# Gathering Player Data
# No data found for pitcher 592238 in the specified date range.
# Gathering Player Data
# No data found for pitcher 596106 in the specified date range.
# Gathering Player Data
# No data found for pitcher 670155 in the specified date range.
# Gathering Player Data
# No data found for pitcher 670579 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641927 in the specified date range.
# Gathering Player Data
# No data found for pitcher 623406 in the specified date range.
# Gathering Player Data
# No data found for pitcher 657570 in the specified date range.
# Gathering Player Data
# No data found for pitcher 641845 in the specified date range.
# Gathering Player Data
# No data found for pitcher 642678 in the specified date range.

# %%
# concatenate all injured pitcher data --> save to epi.../cohorts/injured/statcast_data.csv
cohort_statcast_data = pd.concat(full_data, ignore_index=True)
cohort_metadata = pd.DataFrame.from_dict(full_metadata, orient='index').reset_index(drop=True)

# save to S3
aws_connection.upload_to_s3(
    cohort_statcast_data, 
    s3_key='epidemiology/cohorts/injured/statcast_data.csv'
)
aws_connection.upload_to_s3(
    cohort_metadata, 
    s3_key='epidemiology/cohorts/injured/statcast_metadata.csv'
)
# Out:
# [AWS]: Uploaded object to s3://pitch-ml/epidemiology/cohorts/injured/statcast_metadata.csv

# %%
# TODO: release position --> arm angle model? for CB group

# %% [markdown]
# $\textbf{Close AWS Connection}$

# %%
aws_connection.close()
# Out:
# [AWS]: Database connection closed.
# [AWS]: SSH tunnel stopped.
